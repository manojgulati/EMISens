# %%
import pandas as pd
import numpy as np
import matplotlib
print matplotlib.get_backend()
matplotlib.use('qt4agg')
print matplotlib.get_backend()
import matplotlib.pyplot as plt
# Out:
# Qt4Agg
# Qt4Agg

# %%
# df is dataframe for backrground EMI noise spectrum in 10Khz-1Mhz
df = pd.read_csv('Controlled Experiments_1\Trace_0000.csv', skiprows=44, names=['Frequency','Noise Amplitude'])

# df_1 is dataframe for EMI noise spectrum from CFL in 10Khz-1Mhz
df_1 = pd.read_csv('Controlled Experiments_1\Trace_0001.csv', skiprows=44, names=['Frequency','CFL Noise Amplitude'])

# df_2 is dataframe for EMI noise spectrum from LED TV in 10Khz-1Mhz
df_2 = pd.read_csv('Controlled Experiments_1\Trace_0002.csv', skiprows=44, names=['Frequency','LEDTV Noise Amplitude'])

# df_3 is dataframe for EMI noise spectrum from LED TV + CFL in 10Khz-1Mhz
df_3 = pd.read_csv('Controlled Experiments_1\Trace_0003.csv', skiprows=44, names=['Frequency','LEDTV+CFL Noise Amplitude'])

# df_4 is dataframe for EMI noise spectrum from PhoneCharger in 10Khz-1Mhz
df_4 = pd.read_csv('Controlled Experiments_1\Trace_0004.csv', skiprows=44, names=['Frequency','PhoneCharger Noise Amplitude'])

# df_5 is dataframe for EMI noise spectrum from USRP in 10Khz-1Mhz
df_5 = pd.read_csv('Controlled Experiments_1\Trace_0005.csv', skiprows=44, names=['Frequency','USRP Noise Amplitude'])

# df_6 is dataframe for EMI noise spectrum from USRP+CFL1 in 10Khz-1Mhz
df_6 = pd.read_csv('Controlled Experiments_1\Trace_0006.csv', skiprows=44, names=['Frequency','USRP+CFL1 Noise Amplitude'])

# df_7 is dataframe for EMI noise spectrum from USRP+CFL2 in 10Khz-1Mhz
df_7 = pd.read_csv('Controlled Experiments_1\Trace_0007.csv', skiprows=44, names=['Frequency','USRP+CFL2 Noise Amplitude'])

# df_8 is dataframe for EMI noise spectrum from USRP+PhoneCharger in 10Khz-1Mhz
df_8 = pd.read_csv('Controlled Experiments_1\Trace_0008.csv', skiprows=44, names=['Frequency','USRP+PhoneCharger Noise Amplitude'])

# df_9 is dataframe for EMI noise spectrum from LED TV in 10Khz-1Mhz
df_9 = pd.read_csv('Controlled Experiments_1\Trace_0009.csv', skiprows=44, names=['Frequency','USRP+PhoneCharger+CFL Noise Amplitude'])

# df_10 is dataframe for EMI noise spectrum from BGN_NoLOAD in 10Khz-1Mhz
df_10 = pd.read_csv('Controlled Experiments_1\Trace_0010.csv', skiprows=44, names=['Frequency','BGN_NoLOAD Noise Amplitude'])

# df_11 is dataframe for EMI noise spectrum from ATX Power Supply in 10Khz-3Mhz
df_11 = pd.read_csv('Controlled Experiments_1\Trace_0011.csv', skiprows=44, names=['Frequency','ATX Power Supply Noise Amplitude'])

# df_12 is dataframe for EMI noise spectrum from BGN+ATX Power Supply in 10Khz-3Mhz
df_12 = pd.read_csv('Controlled Experiments_1\Trace_0012.csv', skiprows=44, names=['Frequency','BGN+ATX Power Supply Noise Amplitude'])

# df_13 is dataframe for EMI noise spectrum from ATX Power Supply2 in 10Khz-1Mhz
df_13 = pd.read_csv('Controlled Experiments_1\Trace_0013.csv', skiprows=44, names=['Frequency','ATX Power Supply2 Noise Amplitude'])


# df_20 is dataframe for EMI noise spectrum from BGN_PLL Power Supply in 10Khz-1Mhz
df_20 = pd.read_csv('Controlled Experiments_1\Trace_0020.csv', skiprows=44, names=['Frequency','BGN_PLL Power Supply Noise Amplitude'])

# df_12 is dataframe for EMI noise spectrum from Microwave(Just Turned On) in 10Khz-1Mhz
df_16 = pd.read_csv('Controlled Experiments_1\Trace_0016.csv', skiprows=44, names=['Frequency','Microwave(Just Turned On) Noise Amplitude'])

# df_17 is dataframe for EMI noise spectrum from MMicrowave(1min mode) in 10Khz-1Mhz
df_17 = pd.read_csv('Controlled Experiments_1\Trace_0017.csv', skiprows=44, names=['Frequency','Microwave(1min mode) Noise Amplitude'])

# df_18 is dataframe for EMI noise spectrum from Microwave(10min mode) in 10Khz-1Mhz
df_18 = pd.read_csv('Controlled Experiments_1\Trace_0018.csv', skiprows=44, names=['Frequency','Microwave(10min mode) Noise Amplitude'])

# df_19 is dataframe for EMI noise spectrum from Microwave(4min mode) in 10Khz-1Mhz
df_19 = pd.read_csv('Controlled Experiments_1\Trace_0019.csv', skiprows=44, names=['Frequency','Microwave(4min mode) Noise Amplitude'])


# df_21 is dataframe for EMI noise spectrum from BGN_PLL_HF Power Supply in 10Khz-3Mhz
df_21 = pd.read_csv('Controlled Experiments_1\Trace_0021.csv', skiprows=44, names=['Frequency','BGN_PLL_HF Power Supply Noise Amplitude'])

# df_22 is dataframe for EMI noise spectrum from Microwave(1min mode HF) in 10Khz-3Mhz
df_22 = pd.read_csv('Controlled Experiments_1\Trace_0022.csv', skiprows=44, names=['Frequency','Microwave(1min mode HF) Noise Amplitude'])

# df_23 is dataframe for EMI noise spectrum from Microwave(10min mode HF) in 10Khz-3Mhz
df_23 = pd.read_csv('Controlled Experiments_1\Trace_0023.csv', skiprows=44, names=['Frequency','Microwave(10min mode HF) Noise Amplitude'])

# df_24 is dataframe for EMI noise spectrum from Microwave(Just Turned On HF) in 10Khz-3Mhz
df_24 = pd.read_csv('Controlled Experiments_1\Trace_0024.csv', skiprows=44, names=['Frequency','Microwave(Just Turned On HF) Noise Amplitude'])

# df_25 is dataframe for EMI noise spectrum from BGN_PLL_HF2 Power Supply in 10Khz-3Mhz
df_25 = pd.read_csv('Controlled Experiments_1\Trace_0025.csv', skiprows=44, names=['Frequency','BGN_PLL_HF2 Power Supply Noise Amplitude'])

#print df[:10]
#print df_1[:10]

# %%
df['Frequency'] = df['Frequency']/1000.; 
df_1['Frequency'] = df_1['Frequency']/1000.; 
df_2['Frequency'] = df_2['Frequency']/1000.; 
df_3['Frequency'] = df_3['Frequency']/1000.; 
df_4['Frequency'] = df_4['Frequency']/1000.;
df_5['Frequency'] = df_5['Frequency']/1000.;
df_6['Frequency'] = df_6['Frequency']/1000.;
df_7['Frequency'] = df_7['Frequency']/1000.;
df_8['Frequency'] = df_8['Frequency']/1000.;
df_9['Frequency'] = df_9['Frequency']/1000.;
df_10['Frequency'] = df_10['Frequency']/1000.;
df_11['Frequency'] = df_11['Frequency']/1000.;
df_12['Frequency'] = df_12['Frequency']/1000.;
df_13['Frequency'] = df_13['Frequency']/1000.;

df_20['Frequency'] = df_20['Frequency']/1000.;
df_16['Frequency'] = df_16['Frequency']/1000.;
df_17['Frequency'] = df_17['Frequency']/1000.;
df_18['Frequency'] = df_18['Frequency']/1000.;
df_19['Frequency'] = df_19['Frequency']/1000.;

df_21['Frequency'] = df_21['Frequency']/1000.;
df_22['Frequency'] = df_22['Frequency']/1000.;
df_23['Frequency'] = df_23['Frequency']/1000.;
df_24['Frequency'] = df_24['Frequency']/1000.;
df_25['Frequency'] = df_25['Frequency']/1000.;


#print df[:10]
#print df_1[:10]
#print df_3[:10]

# %%
#df.plot()
#fig = plt.gcf();
ax = plt.gca();
ax.grid(True);

# Plot for Background Noise
#plt.plot(df['Frequency'], df['Noise Amplitude'])

# Plot for CFL Noise
#plt.plot(df_1['Frequency'], df_1['CFL Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_2['Frequency'], df_2['LEDTV Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_3['Frequency'], df_3['LEDTV+CFL Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_4['Frequency'], df_4['PhoneCharger Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_5['Frequency'], df_5['USRP Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_6['Frequency'], df_6['USRP+CFL1 Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_7['Frequency'], df_7['USRP+CFL2 Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_8['Frequency'], df_8['USRP+PhoneCharger Noise Amplitude'])

# Plot for USRP+PhoneCharger+CFL Noise
#plt.plot(df_9['Frequency'], df_9['USRP+PhoneCharger+CFL Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_10['Frequency'], df_10['BGN_NoLOAD Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_11['Frequency'], df_11['ATX Power Supply Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_12['Frequency'], df_12['BGN+ATX Power Supply Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_13['Frequency'], df_13['ATX Power Supply2 Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_20['Frequency'], df_20['BGN_PLL Power Supply Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_16['Frequency'], df_16['Microwave(Just Turned On) Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_17['Frequency'], df_17['Microwave(1min mode) Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_18['Frequency'], df_18['Microwave(10min mode) Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_19['Frequency'], df_19['Microwave(4min mode) Noise Amplitude'])

# Plot for LED Tv Noise
plt.plot(df_21['Frequency'], df_21['BGN_PLL_HF Power Supply Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_22['Frequency'], df_22['Microwave(1min mode HF) Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_23['Frequency'], df_23['Microwave(10min mode HF) Noise Amplitude'])

# Plot for LED Tv Noise
#plt.plot(df_24['Frequency'], df_24['Microwave(Just Turned On HF) Noise Amplitude'])

# Plot for LED Tv Noise
plt.plot(df_25['Frequency'], df_25['BGN_PLL_HF2 Power Supply Noise Amplitude'])

plt.xlabel("Frequency ( in Khz)");
plt.ylabel("Amplitude ( in dBm)");
plt.ylim((-140, -90))
#plt.legend(['Background Noise','CFL Noise']);
#plt.legend(['Background Noise','LEDTV Noise']);
#plt.legend(['Background Noise','LEDTV+CFL Noise']);
plt.legend(['BGN_PLL_HF Noise','BGN_PLL_HF2 Power Supply Noise']);
mng = plt.get_current_fig_manager()
mng.window.showMaximized()
plt.savefig("BGN+BGN_PLL_HF2 Power Supply.png");

plt.show();
